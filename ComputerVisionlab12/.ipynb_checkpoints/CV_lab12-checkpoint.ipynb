# %%
import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import timeit

# %%
def show(img):
    if (len(img.shape) == 2):
        display(Image.fromarray(img));    
    else:
        display(Image.fromarray(img[:,:,::-1]));

# %%
start = timeit.timeit()
img = cv2.imread('Chess/001.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h:img_h-100,img_w-210:img_w-350]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=140x118 at 0x7FD8EDFB11F0>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.008296261996292742

# %%
start = timeit.timeit()
img = cv2.imread('Chess/002.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h:img_h-120,img_w-900:img_w-200]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=80x98 at 0x7FD8F0C09580>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.02084602300237748

# %%
start = timeit.timeit()
img = cv2.imread('Chess/003.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h:img_h-150,img_w-175:img_w-385]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=70x68 at 0x7FD8EDFB10A0>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.03735730699918349

# %%
start = timeit.timeit()
img = cv2.imread('Chess/004.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h:img_h-150,img_w-175:img_w-385]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=70x68 at 0x7FD8EDFB1430>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.05261575899930904

# %%
start = timeit.timeit()
img = cv2.imread('Chess/005.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h:img_h-110,img_w-130:img_w-300]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=110x108 at 0x7FD8EDFB1FA0>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.04456872900118469

# %%
start = timeit.timeit()
img = cv2.imread('Chess/006.png')
#show(img)
img_l,img_w,img_h=img.shape
img = img[img_h-180:img_h-85,img_w-220:img_w-310]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=190x95 at 0x7FD8EDFB18B0>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.01286838900341536

# %%
start = timeit.timeit()
img = cv2.imread('Chess/chess.png')
#show(img)
scale_percent = 10 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=440x350 at 0x7FD8EDFB1CA0>

# %%
end = timeit.timeit()
print(end - start)
# Out:
# 0.035989505999168614
