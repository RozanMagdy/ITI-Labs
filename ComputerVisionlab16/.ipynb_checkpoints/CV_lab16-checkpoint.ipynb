# %%
# !pip install tensorflow_datasets
# Out:
# Collecting tensorflow_datasets
#   Downloading tensorflow_datasets-4.3.0-py3-none-any.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (2.24.0)
# Requirement already satisfied: future in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (0.18.2)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.0.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=18.1.0 in /home/rouzan/.local/lib/python3.8/site-packages (from tensorflow_datasets) (20.3.0)
# Requirement already satisfied: numpy in /home/rouzan/.local/lib/python3.8/site-packages (from tensorflow_datasets) (1.20.2)
# Requirement already satisfied: absl-py in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (0.10.0)
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-5.1.4-py3-none-any.whl (26 kB)
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 1.1 MB/s eta 0:00:01
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Requirement already satisfied: termcolor in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: tqdm in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (4.50.2)
# Requirement already satisfied: protobuf>=3.12.2 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (3.13.0)
# Requirement already satisfied: six in /home/rouzan/anaconda3/lib/python3.8/site-packages (from tensorflow_datasets) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rouzan/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->tensorflow_datasets) (2020.6.20)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/rouzan/anaconda3/lib/python3.8/site-packages (from importlib-resources; python_version < "3.9"->tensorflow_datasets) (3.4.0)
# Requirement already satisfied: setuptools in /home/rouzan/anaconda3/lib/python3.8/site-packages (from protobuf>=3.12.2->tensorflow_datasets) (50.3.1.post20201107)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=90a2cb80a37908a03f18f125c8f5b91f9938c1f2cd095e9145069a3e118393fa
#   Stored in directory: /home/rouzan/.cache/pip/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
# Successfully built promise
# Installing collected packages: googleapis-common-protos, tensorflow-metadata, importlib-resources, dill, promise, tensorflow-datasets
# Successfully installed dill-0.3.4 googleapis-common-protos-1.53.0 importlib-resources-5.1.4 promise-2.3 tensorflow-datasets-4.3.0 tensorflow-metadata-1.0.0

# %%
# Import TensorFlow Datasets
import tensorflow_datasets as tfds
import tensorflow as tf

# Helper libraries
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
print (tf.__version__)
# Out:
# 2.2.0

# %%
dataset, metadata = tfds.load('fashion_mnist', as_supervised=True, with_info=True)
train_dataset, test_dataset = dataset['train'], dataset['test']

# %%
def normalize(images, labels):
    images = tf.cast(images, tf.float32)
    images /= 255
    return images, labels

train_dataset =  train_dataset.map(normalize)
test_dataset  =  test_dataset.map(normalize)

# %%
for image, label in test_dataset.take(2):
      break
image = image.numpy().reshape((28,28))

plt.figure()
plt.imshow(image, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
i = 0
for (image, label) in test_dataset.take(25):
    image = image.numpy().reshape((28,28))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image, cmap=plt.cm.binary)
    i += 1
plt.show()

# %%
BATCH_SIZE = 32
train_dataset = train_dataset.cache().repeat().shuffle(60000).batch(BATCH_SIZE)
test_dataset = test_dataset.cache().batch(BATCH_SIZE)

# %%
print (train_dataset)
# Out:
# <BatchDataset shapes: ((None, 28, 28, 1), (None,)), types: (tf.float32, tf.int64)>

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(30, activation='sigmoid'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_20 (Dense)             (None, 30)                3870
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                310
# =================================================================
# Total params: 104,660
# Trainable params: 104,660
# Non-trainable params: 0
# _________________________________________________________________

# %%
with open('modelsummary.txt', 'w') as f:

    model.summary(print_fn=lambda x: f.write(x + '\n'))

# %%
tf.keras.utils.plot_model(
        model,
        to_file='model.png',
        show_layer_names=True,
        show_shapes=True
    )

# %%
hist = model.fit(train_dataset, epochs=10, steps_per_epoch=math.ceil(60000/BATCH_SIZE))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5701 - accuracy: 0.8185
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3797 - accuracy: 0.8644
# Epoch 3/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3382 - accuracy: 0.8778
# Epoch 4/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3081 - accuracy: 0.8865
# Epoch 5/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2975 - accuracy: 0.8902
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2758 - accuracy: 0.8977
# Epoch 7/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2692 - accuracy: 0.9003
# Epoch 8/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.2571 - accuracy: 0.9052
# Epoch 9/10
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.2483 - accuracy: 0.9086
# Epoch 10/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2318 - accuracy: 0.9144

# %%
est_loss, test_accuracy = model.evaluate(test_dataset, steps=math.ceil(10000/BATCH_SIZE))
print('Accuracy on test dataset:', test_accuracy)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3331 - accuracy: 0.8828
# Accuracy on test dataset: 0.8827999830245972

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.plot(hist.history['loss']);
plt.plot(hist.history['accuracy']);

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(hist.history['accuracy']);

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# %%
tflite_model_file = "mnist_model.tflite"
open(tflite_model_file, 'wb').write(tflite_model)
# Out:
# 420484
